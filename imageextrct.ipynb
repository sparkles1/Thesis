# %% [markdown]
# <a href="https://colab.research.google.com/github/sparkles1/Thesis/blob/master/imageextrct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install PyDrive
# Out:
# Mounted at /content/drive
# ...

# %%
# Importing all necessary libraries 

import cv2
import os
import numpy as np

# %%
# Read the video from specified path 
root_dir = "/content/drive/My Drive/VideoSpeechFile/"
audio_only_labels =[]

for subdirs, dirs, files in os.walk(root_dir, topdown=False):
  for dire in dirs:
    continue
    for file in files:
      print(root_dir+dire+'/'+file)
      cam = cv2.VideoCapture(root_dir+dire+'/'+file) 

try: 
    # creating a folder named data 
    if not os.path.exists('data'): 
      os.makedirs('data')

    # if not created then raise error 
except OSError: 
  print ('Error: Creating directory of data') 

try:
  # creating a individual folders 
  if os.path.exists('data'):
    if not os.path.exists('data/neutral'):
      os.makedirs('data/neutral')
    if not os.path.exists('data/calm'):
      os.makedirs('data/calm')
    if not os.path.exists('data/happy'):
      os.makedirs('data/happy')
    if not os.path.exists('data/sad'):
      os.makedirs('data/sad')
    if not os.path.exists('data/angry'):
      os.makedirs('data/angry')
    if not os.path.exists('data/fearful'):
      os.makedirs('data/fearful')
    if not os.path.exists('data/disgust'):
      os.makedirs('data/disgust')
    if not os.path.exists('data/surprised'):
      os.makedirs('data/surprised')
    if not os.path.exists('data/none'):
      os.makedirs('data/none')
except OSError: 
  print ('Error: Creating individual directory of data') 
'''

      # frame 
      currentframe = 0
      print(currentframe)

      while(True): 
      # reading from frame 
        ret,frame = cam.read() 

        if ret: 
          # if video is still left continue creating images 
          if(str(int(file[7:8])-1) == '1'):
            name = '.data/neutral' + str(currentframe) + '.jpg'
            print ('Creating...' + name) 
          elif(str(int(file[7:8])-1) == '2'):
            name = '.data/calm' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '3'):
            name = '.data/happy' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '4'):
            name = '.data/sad' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '5'):
            name = '.data/angry' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '6'):
            name = '.data/fearful' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '7'):
            name = '.data/disgust' + str(currentframe) + '.jpg'
            print ('Creating...' + name)
          elif(str(int(file[7:8])-1) == '8'):
            name = '.data/surprised' + str(currentframe) + '.jpg'
            print ('Creating...' + name)

              # writing the extracted images 
              cv2.imwrite(os.path.join(name), frame)

              # increasing counter so that it will 
              # show how many frames are created 
              currentframe += 1
            else: 
                break


          # Release all space and windows once done 
          cam.release() 
          cv2.destroyAllWindows() 
'''
# Out:
# "\n\n      # frame \n      currentframe = 0\n      print(currentframe)\n\n      while(True): \n      # reading from frame \n        ret,frame = cam.read() \n\n        if ret: \n          # if video is still left continue creating images \n          if(str(int(file[7:8])-1) == '1'):\n            name = '.data/neutral' + str(currentframe) + '.jpg'\n            print ('Creating...' + name) \n          elif(str(int(file[7:8])-1) == '2'):\n            name = '.data/calm' + str(currentframe) + '.jpg'\n            print ('Creating...' + name)\n          elif(str(int(file[7:8])-1) == '3'):\n            name = '.data/happy' + str(currentframe) + '.jpg'\n            print ('Creating...' + name)\n          elif(str(int(file[7:8])-1) == '4'):\n            name = '.data/sad' + str(currentframe) + '.jpg'\n            print ('Creating...' + name)\n          elif(str(int(file[7:8])-1) == '5'):\n            name = '.data/angry' + str(currentframe) + '.jpg'\n            print ('Creating...' + name)\n 
# ...

# %%
# Read the video from specified path 
root_dir = "/content/drive/My Drive/VideoSpeechFile/"
audio_only_labels =[]
# frame 
for subdirs, dirs, files in os.walk(root_dir, topdown=False):
  #print(subdirs)
  for file in files:
    print(file)
    cam = cv2.VideoCapture(os.path.join(subdirs, file))
    # reading from frame 
    currentframe = 0
    ret,frame = cam.read()
    #print(ret,frame)
    #print(currentframe)
    #print(int(file[7:8]))
    while(ret):
      

      # if video is still left continue creating images  
      if(str(int(file[7:8]))== '1'):
        fn=root_dir+'data'
        name = './data/neutral/neutral' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        print('Creating...' + name)
      if(str(int(file[7:8])-1) == '2'):
        fn=root_dir+'data/calm'
        name = './data/calm/calm' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '3'):
        fn=root_dir+'data/happy'
        name = './data/happy/happy' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '4'):
        fn=root_dir+'data/sad'
        name = './data/sad/sad' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '5'):
        fn=root_dir+'data/angry'
        name = './data/angry/angry' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        currentframe += 1
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '6'):
        fn=root_dir+'data/fearful/'
        name = './data/fearful/fearful' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        currentframe += 1
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '7'):
        fn=root_dir+'data/disgust/'
        name = './data/disgust/disgust' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
        currentframe += 1
        print ('Creating...' + name)
      if(str(int(file[7:8])-1) == '8'):
        name = './data/surprised/surprised' + str(currentframe) + '.jpg'
        cv2.imwrite(name,frame)
    
      
      ret,frame = cam.read()
      currentframe += 1
        #print ('Creating...' + name)
    # writing the extracted images 
    #print(name)
    #cv2.imwrite(os.path.join(fn,name),frame)blob:https://colab.research.google.com/7408f2ed-5dce-416d-934f-3c0a34af2f06
    #currentframe += 1
  # increasing counter so that it will 
  # show how many frames are created 

# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# 01-01-01-01-01-01-22.mp4
# Creating..../data/neutral/neutral0.jpg
# Creating..../data/neutral/neutral1.jpg
# Creating..../data/neutral/neutral2.jpg
# Creating..../data/neutral/neutral3.jpg
# Creating..../data/neutral/neutral4.jpg
# Creating..../data/neutral/neutral5.jpg
# Creating..../data/neutral/neutral6.jpg
# Creating..../data/neutral/neutral7.jpg
# Creating..../data/neutral/neutral8.jpg
# Creating..../data/neutral/neutral9.jpg
# Creating..../data/neutral/neutral10.jpg
# Creating..../data/neutral/neutral11.jpg
# Creating..../data/neutral/neutral12.jpg
# Creating..../data/neutral/neutral13.jpg
# Creating..../data/neutral/neutral14.jpg
# Creating..../data/neutral/neutral15.jpg
# Creating..../data/neutral/neutral16.jpg
# Creating..../data/neutral/neutral17.jpg
# Creating..../data/neutral/neutral18.jpg
# Creating..../data/neutral/neutral19.jpg
# Creating..../data/neutral/neutral20.jpg
# Creating..../data/neutral/neutral21.jpg
# Creating..../data/neutral/neutral22.jpg
# ...

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
